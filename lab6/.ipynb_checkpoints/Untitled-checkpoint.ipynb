# %%
from pymongo import MongoClient
from random import randint
from pprint import pprint

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Create a connection

# %%
host = "mongodb://mongo:27017/", #if within docker.

# NOTE: if you are running this notebook in docker you need to 
# refer to the container name "mongodb://mongo:27017/"
# mongo = "mongo"

# we use the MongoClient to communicate with the running database instance.
myclient = MongoClient(
                    host,  
                    username='admin',
                    password='admin') #Mongo URI format

# Or you can use the attribute style 
# mydb = myclient.customer_db

# %% [markdown]
# # Create a Dtabase

# %%
mydb = myclient["customer_db"]

# %%
myclient.list_database_names()
# Out:
# ['admin', 'config', 'local', 'mydb']

# %% [markdown]
# # Create a collection

# %%
customers = mydb['customers']

# %%
mydb.list_collection_names()
# Out:
# []

# %%
myclient.list_database_names()
# Out:
# ['admin', 'config', 'local', 'mydb']

# %% [markdown]
# ## MongoDB is Lazy

# %%
first_customer_doc = {"name": "Jane", "age": 25, "gender": "female"}

# %%
customers.insert_one(first_customer_doc)

# %%
mydb.list_collection_names()
# Out:
# ['customers']

# %%
myclient.list_database_names()
# Out:
# ['admin', 'config', 'customer_db', 'local', 'mydb']

# %%
c = customers.find_one()

# %%
c
# Out:
# {'_id': ObjectId('6926c236298f27673a93246f'),
#  'name': 'Jane',
#  'age': 25,
#  'gender': 'female'}

# %% [markdown]
# ### About IDs

# %% [markdown]
# **Notes about Document_IDs:**
# - Although these identifiers look pretty random, there is actually a wel defined structure.
#     - The first 8 characters (4 bytes) are a timestamp
#     - followed by a 6 character machine identifier
#     - then a 4 character process identifier
#     - and finally a 6 character counter.
#
# - <font color='red'> Note to consider</font>:
#     - Instead of creating the default _id(s) here, we can use the _id as our given IDs in the Dataset
#     - it's better to stick to the automatically created mongo IDs in order to scale well.
#     - However, sometimes you badly want to prettify the never-ending ObjectID value.
#         - Then, you should consider using an appropriate atomic increment strategy.
#    ```javascript
#    db.coll.insert_one({_id:"myUniqueValue", a:1, b:1}) ```

# %%
mydb.customers.insert_one({"_id":"qwe2312312", "name": "Riccardo", "age": 35, "gender": "male"})
# Out:
# InsertOneResult('qwe2312312', acknowledged=True)

# %%
cs = customers.find({})

# %%
for  c in cs:
    print(c)
# Out:
# {'_id': ObjectId('6926c236298f27673a93246f'), 'name': 'Jane', 'age': 25, 'gender': 'female'}
# {'_id': 'qwe2312312', 'name': 'Riccardo', 'age': 35, 'gender': 'male'}

# %% [markdown]
# ## Let's filter the results

# %%
cs = customers.find({"age":35})
for  c in cs:
    print(c)
# Out:
# {'_id': 'qwe2312312', 'name': 'Riccardo', 'age': 35, 'gender': 'male'}

# %%
cs = customers.find({"age": {"$lt": 30}})
for  c in cs:
    print(c)
# Out:
# {'_id': ObjectId('6926c236298f27673a93246f'), 'name': 'Jane', 'age': 25, 'gender': 'female'}

# %% [markdown]
# # Selection

# %% [markdown]
# [operators](./mongodb-query-operators-examples.jpg)

# %%
cs = customers.find({"_id":"qwe2312312"})
for  c in cs:
    print(c)
# Out:
# {'_id': 'qwe2312312', 'name': 'Riccardo', 'age': 35, 'gender': 'male'}

# %% [markdown]
# # Projection

# %%
cs = customers.find({"age": {"$lt": 30}} # selection
                    ,{"name": 1} #projection
                   )
for  c in cs:
    print(c)
# Out:
# {'_id': ObjectId('6926c236298f27673a93246f'), 'name': 'Jane'}

# %% [markdown]
# # Sort

# %%
customers_to_insert = [{"name":"Caresa","age":7,"gender":"Female"},
{"name":"Bartolomeo","age":64,"gender":"Male"},
{"name":"Leslie","age":43,"gender":"Male"},
{"name":"Karmen","age":33,"gender":"Female"},
{"name":"Noble","age":98,"gender":"Male"},
{"name":"Ashby","age":86,"gender":"Male"},
{"name":"Tabbie","age":23,"gender":"Male"},
{"name":"Gareth","age":17,"gender":"Male"},
{"name":"Silvester","age":49,"gender":"Male"},
{"name":"Jolene","age":69,"gender":"Female"}]

# %%
mydb.customers.insert_many(customers_to_insert)
# Out:
# InsertManyResult([ObjectId('6926c82d298f27673a932470'), ObjectId('6926c82d298f27673a932471'), ObjectId('6926c82d298f27673a932472'), ObjectId('6926c82d298f27673a932473'), ObjectId('6926c82d298f27673a932474'), ObjectId('6926c82d298f27673a932475'), ObjectId('6926c82d298f27673a932476'), ObjectId('6926c82d298f27673a932477'), ObjectId('6926c82d298f27673a932478'), ObjectId('6926c82d298f27673a932479')], acknowledged=True)

# %%
cs = customers.find({} # selection
                    ,{"name": 1} #projection
                   ).sort({"age":1})
for  c in cs:
    print(c)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[72], line 4
#       1 cs = customers.find({} # selection
#       2                     ,{"name": 1} #projection
#       3                    ).sort({"age":0})
# ----> 4 for  c in cs:
#       5     print(c)
#
# File /opt/conda/lib/python3.13/site-packages/pymongo/synchronous/cursor.py:1289, in Cursor.__next__(self)
#    1288 def __next__(self) -> _DocumentType:
# -> 1289     return self.next()
#
# File /opt/conda/lib/python3.13/site-packages/pymongo/synchronous/cursor.py:1265, in Cursor.next(self)
#    1263 if self._empty:
#    1264     raise StopIteration
# -> 1265 if len(self._data) or self._refresh():
#    1266     return self._data.popleft()
#    1267 else:
#
# File /opt/conda/lib/python3.13/site-packages/pymongo/synchronous/cursor.py:1213, in Cursor._refresh(self)
#    1191         raise InvalidOperation(
#    1192             "Passing a 'hint' is required when using the min/max query"
#    1193             " option to ensure the query utilizes the correct index"
#    1194         )
#    1195     q = self._query_class(
#    1196         self._query_flags,
#    1197         self._collection.database.name,
#    (...)   1211         self._exhaust,
#    1212     )
# -> 1213     self._send_message(q)
#    1214 elif self._id:  # Get More
#    1215     if self._limit:
#
# File /opt/conda/lib/python3.13/site-packages/pymongo/synchronous/cursor.py:1108, in Cursor._send_message(self, operation)
#    1105     raise InvalidOperation("exhaust cursors do not support auto encryption")
#    1107 try:
# -> 1108     response = client._run_operation(
#    1109         operation, self._unpack_response, address=self._address
#    1110     )
#    1111 except OperationFailure as exc:
#    1112     if exc.code in _CURSOR_CLOSED_ERRORS or self._exhaust:
#    1113         # Don't send killCursors because the cursor is already closed.
#
# File /opt/conda/lib/python3.13/site-packages/pymongo/_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File /opt/conda/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:1938, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1928     operation.reset()  # Reset op in case of retry.
#    1929     return server.run_operation(
#    1930         conn,
#    1931         operation,
#    (...)   1935         self,
#    1936     )
# -> 1938 return self._retryable_read(
#    1939     _cmd,
#    1940     operation.read_preference,
#    1941     operation.session,  # type: ignore[arg-type]
#    1942     address=address,
#    1943     retryable=isinstance(operation, _Query),
#    1944     operation=operation.name,
#    1945 )
#
# File /opt/conda/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:2047, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    2042 # Ensure that the client supports retrying on reads and there is no session in
#    2043 # transaction, otherwise, we will not support retry behavior for this call.
#    2044 retryable = bool(
#    2045     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    2046 )
# -> 2047 return self._retry_internal(
#    2048     func,
#    2049     session,
#    2050     None,
#    2051     operation,
#    2052     is_read=True,
#    2053     address=address,
#    2054     read_pref=read_pref,
#    2055     retryable=retryable,
#    2056     operation_id=operation_id,
#    2057 )
#
# File /opt/conda/lib/python3.13/site-packages/pymongo/_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File /opt/conda/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:2014, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1977 @_csot.apply
#    1978 def _retry_internal(
#    1979     self,
#    (...)   1988     operation_id: Optional[int] = None,
#    1989 ) -> T:
#    1990     """Internal retryable helper for all client transactions.
#    1991
#    1992     :param func: Callback function we want to retry
#    (...)   2001     :return: Output of the calling func()
#    2002     """
#    2003     return _ClientConnectionRetryable(
#    2004         mongo_client=self,
#    2005         func=func,
#    2006         bulk=bulk,
#    2007         operation=operation,
#    2008         is_read=is_read,
#    2009         session=session,
#    2010         read_pref=read_pref,
#    2011         address=address,
#    2012         retryable=retryable,
#    2013         operation_id=operation_id,
# -> 2014     ).run()
#
# File /opt/conda/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:2765, in _ClientConnectionRetryable.run(self)
#    2763 self._check_last_error(check_csot=True)
#    2764 try:
# -> 2765     return self._read() if self._is_read else self._write()
#    2766 except ServerSelectionTimeoutError:
#    2767     # The application may think the write was never attempted
#    2768     # if we raise ServerSelectionTimeoutError on the retry
#    2769     # attempt. Raise the original exception instead.
#    2770     self._check_last_error()
#
# File /opt/conda/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:2926, in _ClientConnectionRetryable._read(self)
#    2918 if self._retrying:
#    2919     _debug_log(
#    2920         _COMMAND_LOGGER,
#    2921         message=f"Retrying read attempt number {self._attempt_number}",
#    (...)   2924         operationId=self._operation_id,
#    2925     )
# -> 2926 return self._func(self._session, self._server, conn, read_pref)
#
# File /opt/conda/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:1929, in MongoClient._run_operation.<locals>._cmd(_session, server, conn, read_preference)
#    1922 def _cmd(
#    1923     _session: Optional[ClientSession],
#    1924     server: Server,
#    1925     conn: Connection,
#    1926     read_preference: _ServerMode,
#    1927 ) -> Response:
#    1928     operation.reset()  # Reset op in case of retry.
# -> 1929     return server.run_operation(
#    1930         conn,
#    1931         operation,
#    1932         read_preference,
#    1933         self._event_listeners,
#    1934         unpack_res,
#    1935         self,
#    1936     )
#
# File /opt/conda/lib/python3.13/site-packages/pymongo/synchronous/helpers.py:47, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      44 from pymongo.synchronous.pool import Connection
#      46 try:
# ---> 47     return func(*args, **kwargs)
#      48 except OperationFailure as exc:
#      49     if no_reauth:
#
# File /opt/conda/lib/python3.13/site-packages/pymongo/synchronous/server.py:227, in Server.run_operation(self, conn, operation, read_preference, listeners, unpack_res, client)
#     225         first = docs[0]
#     226         operation.client._process_response(first, operation.session)  # type: ignore[misc, arg-type]
# --> 227         _check_command_response(first, conn.max_wire_version, pool_opts=conn.opts)  # type:ignore[has-type]
#     228 except Exception as exc:
#     229     duration = datetime.now() - start
#
# File /opt/conda/lib/python3.13/site-packages/pymongo/helpers_shared.py:284, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error, pool_opts)
#     281 elif code == 43:
#     282     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 284 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: $sort key ordering must be 1 (for ascending) or -1 (for descending), full error: {'ok': 0.0, 'errmsg': '$sort key ordering must be 1 (for ascending) or -1 (for descending)', 'code': 15975, 'codeName': 'Location15975'}

# %% [markdown]
# # Updates
